# %%
#  import các thư viện

# %%
import pandas as pd 
import matplotlib.pyplot as plt
import seaborn as sns

# %%
#  Đọc file dữ liệu

# %%
df = pd.read_csv("train.csv")
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
#  Kiểm tra giá trị null của các hàng

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  891 non-null    int64
#  1   Survived     891 non-null    int64
#  2   Pclass       891 non-null    int64
#  3   Name         891 non-null    object
#  4   Sex          891 non-null    object
#  5   Age          714 non-null    float64
#  6   SibSp        891 non-null    int64
#  7   Parch        891 non-null    int64
#  8   Ticket       891 non-null    object
#  9   Fare         891 non-null    float64
#  10  Cabin        204 non-null    object
#  11  Embarked     889 non-null    object
# dtypes: float64(2), int64(5), object(5)
# memory usage: 83.7+ KB

# %%
df.describe()
# Out:
#        PassengerId    Survived      Pclass         Age       SibSp  \
# count   891.000000  891.000000  891.000000  714.000000  891.000000
# mean    446.000000    0.383838    2.308642   29.699118    0.523008
# std     257.353842    0.486592    0.836071   14.526497    1.102743
# min       1.000000    0.000000    1.000000    0.420000    0.000000
# 25%     223.500000    0.000000    2.000000   20.125000    0.000000
# 50%     446.000000    0.000000    3.000000   28.000000    0.000000
# 75%     668.500000    1.000000    3.000000   38.000000    1.000000
# max     891.000000    1.000000    3.000000   80.000000    8.000000
#
#             Parch        Fare
# count  891.000000  891.000000
# mean     0.381594   32.204208
# std      0.806057   49.693429
# min      0.000000    0.000000
# 25%      0.000000    7.910400
# 50%      0.000000   14.454200
# 75%      0.000000   31.000000
# max      6.000000  512.329200

# %%
#  Biểu đồ sự phân bố các giá trị trong nhóm:Pclass, Age,SibSp,Parch,Fare

# %%
df_num = df[['Pclass','Age','SibSp','Parch','Fare']]
df_num.columns
# Out:
# Index(['Pclass', 'Age', 'SibSp', 'Parch', 'Fare'], dtype='object')

# %%
for i in df_num.columns:
    plt.hist(df_num[i])
    plt.title(i)
    plt.show()

# %%
# Tìm mối liên hệ giữa các biến định lượng

# %%
print(df_num.corr())
# Out:
#           Pclass       Age     SibSp     Parch      Fare
# Pclass  1.000000 -0.369226  0.083081  0.018443 -0.549500
# Age    -0.369226  1.000000 -0.308247 -0.189119  0.096067
# SibSp   0.083081 -0.308247  1.000000  0.414838  0.159651
# Parch   0.018443 -0.189119  0.414838  1.000000  0.216225
# Fare   -0.549500  0.096067  0.159651  0.216225  1.000000

# %%
sns.heatmap(df_num.corr());

# %%
#  Tạo pivot table giữa các biến định tính với khả năng sống sót

# %%
pd.pivot_table(df, values=['Age','SibSp','Parch', 'Fare'], index='Survived')
# Out:
#                 Age       Fare     Parch     SibSp
# Survived
# 0         30.626179  22.117887  0.329690  0.553734
# 1         28.343690  48.395408  0.464912  0.473684

# %%
df.Parch.value_counts()
# Out:
# 0    678
# 1    118
# 2     80
# 3      5
# 5      5
# 4      4
# 6      1
# Name: Parch, dtype: int64

# %%
#  buil train modeling( hồi quy logic)

# %%
from sklearn.linear_model import LogisticRegression
lr = LogisticRegression()
x = df[['Age','Fare','Parch','SibSp']]
y= df['Survived']

# %%
x.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 4 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Age     714 non-null    float64
#  1   Fare    891 non-null    float64
#  2   Parch   891 non-null    int64
#  3   SibSp   891 non-null    int64
# dtypes: float64(2), int64(2)
# memory usage: 28.0 KB

# %%
df.Age.mean()
# Out:
# 29.69911764705882

# %%
x.Age = x.Age.fillna(df.Age.mean())
# Out:
# c:\users\windows 10\appdata\local\programs\python\python39\lib\site-packages\pandas\core\generic.py:5494: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self[name] = value

# %%
lr.fit(x,y)
# Out:
# LogisticRegression()

# %%
lr.coef_
# Out:
# array([[-0.02344398,  0.01873353,  0.10792189, -0.31661367]])

# %%
lr.intercept_
# Out:
# array([-0.22534414])

# %%
lr.score(x,y)*100
# Out:
# 69.1358024691358

# %%
#  Kiểm tra lại bằng tập dữ liệu 'test.csv'
#  đọc dữ liệu

# %%
df1 = pd.read_csv('test.csv')
df1
# Out:
#      PassengerId  Pclass                                          Name  \
# 0            892       3                              Kelly, Mr. James
# 1            893       3              Wilkes, Mrs. James (Ellen Needs)
# 2            894       2                     Myles, Mr. Thomas Francis
# 3            895       3                              Wirz, Mr. Albert
# 4            896       3  Hirvonen, Mrs. Alexander (Helga E Lindqvist)
# ..           ...     ...                                           ...
# 413         1305       3                            Spector, Mr. Woolf
# 414         1306       1                  Oliva y Ocana, Dona. Fermina
# 415         1307       3                  Saether, Mr. Simon Sivertsen
# 416         1308       3                           Ware, Mr. Frederick
# 417         1309       3                      Peter, Master. Michael J
#
#         Sex   Age  SibSp  Parch              Ticket      Fare Cabin Embarked
# ...

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 418 entries, 0 to 417
# Data columns (total 11 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  418 non-null    int64
#  1   Pclass       418 non-null    int64
#  2   Name         418 non-null    object
#  3   Sex          418 non-null    object
#  4   Age          332 non-null    float64
#  5   SibSp        418 non-null    int64
#  6   Parch        418 non-null    int64
#  7   Ticket       418 non-null    object
#  8   Fare         417 non-null    float64
#  9   Cabin        91 non-null     object
#  10  Embarked     418 non-null    object
# dtypes: float64(2), int64(4), object(5)
# memory usage: 36.0+ KB

# %%
x1 = df1[['Age','Fare','Parch','SibSp']]

# %%
#  điền các giá trị trống bằng giá trị trùng bình của cột Age,Fare

# %%
x1.Age = x1.Age.fillna(x1.Age.mean())

# %%
x1.Fare = x1.Fare.fillna(x1.Fare.mean())

# %%
x1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 418 entries, 0 to 417
# Data columns (total 4 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Age     418 non-null    float64
#  1   Fare    418 non-null    float64
#  2   Parch   418 non-null    int64
#  3   SibSp   418 non-null    int64
# dtypes: float64(2), int64(2)
# memory usage: 13.2 KB

# %%
# Dự đoán bằng tập dữ liệu test

# %%
df1.survived = lr.predict(x1)
# Out:
# <ipython-input-67-af8dbc9cc9e5>:1: UserWarning: Pandas doesn't allow columns to be created via a new attribute name - see https://pandas.pydata.org/pandas-docs/stable/indexing.html#attribute-access
#   df1.survived = lr.predict(x1)

# %%
survived = pd.DataFrame(lr.predict(x1))

# %%
survived.value_counts()
# Out:
# 0    349
# 1     69
# dtype: int64

# %%
#  Số lượng sống sót là: 69, thiệt mạng:349

# %%
df1['predict'] = survived

# %%
df1.head()
# Out:
#    PassengerId  Pclass                                          Name     Sex  \
# 0          892       3                              Kelly, Mr. James    male
# 1          893       3              Wilkes, Mrs. James (Ellen Needs)  female
# 2          894       2                     Myles, Mr. Thomas Francis    male
# 3          895       3                              Wirz, Mr. Albert    male
# 4          896       3  Hirvonen, Mrs. Alexander (Helga E Lindqvist)  female
#
#     Age  SibSp  Parch   Ticket     Fare Cabin Embarked  predict
# 0  34.5      0      0   330911   7.8292   NaN        Q        0
# 1  47.0      1      0   363272   7.0000   NaN        S        0
# 2  62.0      0      0   240276   9.6875   NaN        Q        0
# 3  27.0      0      0   315154   8.6625   NaN        S        0
# 4  22.0      1      1  3101298  12.2875   NaN        S        0

# %%
#  kiểm tra lại sự dự đoán
#  Đọc tập dữ liệu có kết quả chính xác

# %%
df2 = pd.read_csv('gender_submission.csv')

# %%
df2.head()
# Out:
#    PassengerId  Survived
# 0          892         0
# 1          893         1
# 2          894         0
# 3          895         0
# 4          896         1

# %%
df1['Sample']=df2['Survived']

# %%
df1.head()
# Out:
#    PassengerId  Pclass                                          Name     Sex  \
# 0          892       3                              Kelly, Mr. James    male
# 1          893       3              Wilkes, Mrs. James (Ellen Needs)  female
# 2          894       2                     Myles, Mr. Thomas Francis    male
# 3          895       3                              Wirz, Mr. Albert    male
# 4          896       3  Hirvonen, Mrs. Alexander (Helga E Lindqvist)  female
#
#     Age  SibSp  Parch   Ticket     Fare Cabin Embarked  predict
# 0  34.5      0      0   330911   7.8292   NaN        Q        0
# 1  47.0      1      0   363272   7.0000   NaN        S        0
# 2  62.0      0      0   240276   9.6875   NaN        Q        0
# 3  27.0      0      0   315154   8.6625   NaN        S        0
# 4  22.0      1      1  3101298  12.2875   NaN        S        0

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 418 entries, 0 to 417
# Data columns (total 13 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  418 non-null    int64
#  1   Pclass       418 non-null    int64
#  2   Name         418 non-null    object
#  3   Sex          418 non-null    object
#  4   Age          418 non-null    float64
#  5   SibSp        418 non-null    int64
#  6   Parch        418 non-null    int64
#  7   Ticket       418 non-null    object
#  8   Fare         418 non-null    float64
#  9   Cabin        91 non-null     object
#  10  Embarked     418 non-null    object
#  11  predict      418 non-null    int64
#  12  Sample       418 non-null    int64
# dtypes: float64(2), int64(6), object(5)
# memory usage: 42.6+ KB

# %%
#  Lấy giá trị cột 'predict'trừ 'Sample' nếu giá trị bằng 0 và 1 là dự đoán đúng nếu bằng "-1" là dự đoán sai

# %%
df1['Eluvated'] =df1['predict']-df1['Sample']

# %%
df1.head()
# Out:
#    PassengerId  Pclass                                          Name     Sex  \
# 0          892       3                              Kelly, Mr. James    male
# 1          893       3              Wilkes, Mrs. James (Ellen Needs)  female
# 2          894       2                     Myles, Mr. Thomas Francis    male
# 3          895       3                              Wirz, Mr. Albert    male
# 4          896       3  Hirvonen, Mrs. Alexander (Helga E Lindqvist)  female
#
#     Age  SibSp  Parch   Ticket     Fare Cabin Embarked  predict
# 0  34.5      0      0   330911   7.8292   NaN        Q        0
# 1  47.0      1      0   363272   7.0000   NaN        S        0
# 2  62.0      0      0   240276   9.6875   NaN        Q        0
# 3  27.0      0      0   315154   8.6625   NaN        S        0
# 4  22.0      1      1  3101298  12.2875   NaN        S        0

# %%
df1['Eluvated'].value_counts()
# Out:
#  0    269
# -1    116
#  1     33
# Name: Eluvated, dtype: int64

# %%
print('Phần trăm chính xác: ',269/df1['Eluvated'].shape[0]*100,'%')
# Out:
# Phần trăm chính xác:  64.35406698564593 %

# %% [markdown]
# # Xây dựng các mô hình khác để dự đoán tốt hơn kết quả, lần này sẽ xử lý dữ liệu theo 1 hướng khác tốt hơn
#  #Let go

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np

# %%
#  Đọc dữ liệu

# %%
df_train = pd.read_csv('train.csv')
df_test = pd.read_csv('test.csv')

# %%
df_train.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
# column with mising values:Age,cabin, Embarked<>

# %%
df_train.describe()
# Out:
#        PassengerId    Survived      Pclass         Age       SibSp  \
# count   891.000000  891.000000  891.000000  714.000000  891.000000
# mean    446.000000    0.383838    2.308642   29.699118    0.523008
# std     257.353842    0.486592    0.836071   14.526497    1.102743
# min       1.000000    0.000000    1.000000    0.420000    0.000000
# 25%     223.500000    0.000000    2.000000   20.125000    0.000000
# 50%     446.000000    0.000000    3.000000   28.000000    0.000000
# 75%     668.500000    1.000000    3.000000   38.000000    1.000000
# max     891.000000    1.000000    3.000000   80.000000    8.000000
#
#             Parch        Fare
# count  891.000000  891.000000
# mean     0.381594   32.204208
# std      0.806057   49.693429
# min      0.000000    0.000000
# 25%      0.000000    7.910400
# 50%      0.000000   14.454200
# 75%      0.000000   31.000000
# max      6.000000  512.329200

# %%
df_test.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 418 entries, 0 to 417
# Data columns (total 11 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  418 non-null    int64
#  1   Pclass       418 non-null    int64
#  2   Name         418 non-null    object
#  3   Sex          418 non-null    object
#  4   Age          332 non-null    float64
#  5   SibSp        418 non-null    int64
#  6   Parch        418 non-null    int64
#  7   Ticket       418 non-null    object
#  8   Fare         417 non-null    float64
#  9   Cabin        91 non-null     object
#  10  Embarked     418 non-null    object
# dtypes: float64(2), int64(4), object(5)
# memory usage: 36.0+ KB

# %%
# column with missing values in test data set: Age, Fare, cabin

# %%
df_train['Title'] = df_train.Name.str.extract(' ([A-Za-z]+)\.', expand=False)

# %%
df_train["Title"].value_counts()
# Out:
# Mr          517
# Miss        182
# Mrs         125
# Master       40
# Dr            7
# Rev           6
# Col           2
# Major         2
# Mlle          2
# Lady          1
# Mme           1
# Sir           1
# Countess      1
# Ms            1
# Don           1
# Capt          1
# Jonkheer      1
# Name: Title, dtype: int64

# %%
# 1.Mã hóa các giá trị trong cột title 
df_train["Title"] = df_train["Title"].replace(["Dr","Rev","Col","Mlle","Major","Lady","Jonkheer","Sir","Mme","Don","Ms","Countess","Capt"],"Rare")
df_train['Title'] = df_train['Title'].map( {'Mr': 1, 'Miss': 2,'Mrs':3,'Master':4,'Rare':5} ).astype(int)

# %%
df_train.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked  Title
# 0      0         A/5 21171   7.2500   NaN        S      1
# 1      0          PC 17599  71.2833   C85        C      3
# 2      0  STON/O2. 3101282   7.9250   NaN        S      2
# 3      0            113803  53.1000  C123        S      3
# ...

# %%
# Mã hóa giá trị trong cột giới tính
df_train['Sex'] = df_train["Sex"].map({'female': 1,'male':0}).astype(int)
#  Xóa các cột không cần thiết
train_df = df_train.drop(['Ticket','Name','Cabin'],axis = 1)

# %%
train_df
# Out:
#      PassengerId  Survived  Pclass  Sex   Age  SibSp  Parch     Fare Embarked  \
# 0              1         0       3    0  22.0      1      0   7.2500        S
# 1              2         1       1    1  38.0      1      0  71.2833        C
# 2              3         1       3    1  26.0      0      0   7.9250        S
# 3              4         1       1    1  35.0      1      0  53.1000        S
# 4              5         0       3    0  35.0      0      0   8.0500        S
# ..           ...       ...     ...  ...   ...    ...    ...      ...      ...
# 886          887         0       2    0  27.0      0      0  13.0000        S
# 887          888         1       1    1  19.0      0      0  30.0000        S
# 888          889         0       3    1   NaN      1      2  23.4500        S
# 889          890         1       1    0  26.0      0      0  30.0000        C
# 890          891         0       3    0  32.0      0      0   7.7500        Q
#
#      Title
# 0        1
# ...

# %%
train_df["Embarked"] = train_df["Embarked"].fillna(train_df.Embarked.dropna().mode()[0])

# %%
train_df.Embarked.dropna().mode()[0]
# Out:
# 'S'

# %%
train_df["Embarked"].value_counts()
# Out:
# S    646
# C    168
# Q     77
# Name: Embarked, dtype: int64

# %%
train_df["Embarked"] = train_df["Embarked"].map({'S':0,'C':1,'Q':2}).astype(int)

# %%
train_df.head()
# Out:
#    PassengerId  Survived  Pclass  Sex   Age  SibSp  Parch     Fare  Embarked  \
# 0            1         0       3    0  22.0      1      0   7.2500         0
# 1            2         1       1    1  38.0      1      0  71.2833         1
# 2            3         1       3    1  26.0      0      0   7.9250         0
# 3            4         1       1    1  35.0      1      0  53.1000         0
# 4            5         0       3    0  35.0      0      0   8.0500         0
#
#    Title
# 0      1
# 1      3
# 2      2
# 3      3
# 4      1

# %%
train_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 10 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  891 non-null    int64
#  1   Survived     891 non-null    int64
#  2   Pclass       891 non-null    int64
#  3   Sex          891 non-null    int32
#  4   Age          714 non-null    float64
#  5   SibSp        891 non-null    int64
#  6   Parch        891 non-null    int64
#  7   Fare         891 non-null    float64
#  8   Embarked     891 non-null    int32
#  9   Title        891 non-null    int32
# dtypes: float64(2), int32(3), int64(5)
# memory usage: 59.3 KB

# %%
train_df['AgeBand'] = pd.cut(train_df['Age'], 5)
train_df[['AgeBand', 'Survived']].groupby(['AgeBand'], as_index=False).mean().sort_values(by='AgeBand', ascending=True)
# Out:
#             AgeBand  Survived
# 0    (0.34, 16.336]  0.550000
# 1  (16.336, 32.252]  0.369942
# 2  (32.252, 48.168]  0.404255
# 3  (48.168, 64.084]  0.434783
# 4    (64.084, 80.0]  0.090909

# %%
#chia thành 4 khoảng nhỏ nhằm đồng bộ với tập giá trị

# %%
train_df['Age'] = train_df['Age'].fillna(train_df.Age.mode()[0])

# %%
train_df['Age']  = df_train['Age']

# %%
train_df.loc[ train_df['Age'] <= 16, 'Age'] = 0
train_df.loc[(train_df['Age'] > 16) & (train_df['Age'] <= 32), 'Age'] = 1
train_df.loc[(train_df['Age'] > 32) & (train_df['Age'] <= 48), 'Age'] = 2
train_df.loc[(train_df['Age'] > 48) & (train_df['Age'] <= 64), 'Age'] = 3
train_df.loc[ train_df['Age'] > 64, 'Age'] = 4

# %%
#  điền giá trị trong cột tuổi bằng số tuổi suất hiện nhiêu nhất
train_df['Age'] = train_df['Age'].fillna(train_df['Age'].mode()[0])

# %%
train_df = train_df.drop('AgeBand', axis = 1)

# %%
train_df
# Out:
#      PassengerId  Survived  Pclass  Sex  Age  SibSp  Parch     Fare  Embarked  \
# 0              1         0       3    0  1.0      1      0   7.2500         0
# 1              2         1       1    1  2.0      1      0  71.2833         1
# 2              3         1       3    1  1.0      0      0   7.9250         0
# 3              4         1       1    1  2.0      1      0  53.1000         0
# 4              5         0       3    0  2.0      0      0   8.0500         0
# ..           ...       ...     ...  ...  ...    ...    ...      ...       ...
# 886          887         0       2    0  1.0      0      0  13.0000         0
# 887          888         1       1    1  1.0      0      0  30.0000         0
# 888          889         0       3    1  1.0      1      2  23.4500         0
# 889          890         1       1    0  1.0      0      0  30.0000         1
# 890          891         0       3    0  1.0      0      0   7.7500         2
#
#      Title
# 0        1
# ...

# %%
from sklearn.svm import SVC, LinearSVC
from sklearn.ensemble import RandomForestClassifier
from sklearn.neighbors import KNeighborsClassifier
from sklearn.naive_bayes import GaussianNB
from sklearn.linear_model import Perceptron
from sklearn.linear_model import SGDClassifier
from sklearn.tree import DecisionTreeClassifier

# %%
# Support vector machine

# %%
 
svc = SVC()
svc.fit(x_train, y_train)
Y_pred = svc.predict(x_test)
acc_svc = round(svc.score(x_train, y_train) * 100, 2)
acc_svc
# Out:
# 68.13

# %%
# Mô Hình KNN

# %%
knn = KNeighborsClassifier(n_neighbors = 3)
knn.fit(x_train, y_train)
Y_pred = knn.predict(x_test)
acc_knn = round(knn.score(x_train, y_train) * 100, 2)
acc_knn
# Out:
# 86.98

# %%
#  Mô hình Gaussian Naive Bayes
gaussian = GaussianNB()
gaussian.fit(x_train, y_train)
Y_pred = gaussian.predict(x_test)
acc_gaussian = round(gaussian.score(x_train, y_train) * 100, 2)
acc_gaussian
# Out:
# 79.24

# %%
#  Mô hình Perceptron

perceptron = Perceptron()
perceptron.fit(x_train, y_train)
Y_pred = perceptron.predict(x_test)
acc_perceptron = round(perceptron.score(x_train, y_train) * 100, 2)
acc_perceptron
# Out:
# 70.82

# %%
#  Mô hình Linear SVC

linear_svc = LinearSVC()
linear_svc.fit(x_train, y_train)
Y_pred = linear_svc.predict(x_test)
acc_linear_svc = round(linear_svc.score(x_train, y_train) * 100, 2)
acc_linear_svc
# Out:
# c:\users\windows 10\appdata\local\programs\python\python39\lib\site-packages\sklearn\svm\_base.py:985: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn("Liblinear failed to converge, increase "
# 81.14

# %%
#  Mo hình Stochastic Gradient Descent

sgd = SGDClassifier()
sgd.fit(x_train, y_train)
Y_pred = sgd.predict(x_test)
acc_sgd = round(sgd.score(x_train, y_train) * 100, 2)
acc_sgd
# Out:
# 78.9

# %%
#  Mô hình Decision Tree

decision_tree = DecisionTreeClassifier()
decision_tree.fit(x_train, y_train)
Y_pred = decision_tree.predict(x_test)
acc_decision_tree = round(decision_tree.score(x_train, y_train) * 100, 2)
acc_decision_tree
# Out:
# 94.5

# %%
#  Mô hình Random Forest

random_forest = RandomForestClassifier(n_estimators=100)
random_forest.fit(x_train, y_train)
Y_pred = random_forest.predict(x_test)
Rd = random_forest.score(x_train, y_train)*100
# acc_random_forest = round(random_forest.score(x_train, x_train) * 100, 2)
# acc_random_forest

# %%
models = pd.DataFrame({
    'Model': ['Support Vector Machines', 'KNN', 'Logistic Regression', 
              'Random Forest', 'Naive Bayes', 'Perceptron', 
              'Stochastic Gradient Decent', 'Linear SVC', 
              'Decision Tree'],
    'Score': [acc_svc, acc_knn, acc_log, 
              Rd, acc_gaussian, acc_perceptron, 
              acc_sgd, acc_linear_svc, acc_decision_tree]})
models.sort_values(by='Score', ascending=False)
# Out:
#                         Model      Score
# 3               Random Forest  94.500561
# 8               Decision Tree  94.500000
# 1                         KNN  86.980000
# 2         Logistic Regression  81.140000
# 7                  Linear SVC  81.140000
# 4                 Naive Bayes  79.240000
# 6  Stochastic Gradient Decent  78.900000
# 5                  Perceptron  70.820000
# 0     Support Vector Machines  68.130000
